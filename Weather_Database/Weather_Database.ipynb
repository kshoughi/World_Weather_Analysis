# %%
# Import the dependencies.
import random
import pandas as pd
import numpy as np
from citipy import citipy
from config import weather_api_key
import requests
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats= np.random.uniform(-90, 90 , size=2000)
lngs= np.random.uniform(-180, 180 , size =2000 )
lat_lngs= zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates= list(lat_lngs)

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# Create a list for holding the cities.
cities=[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city= citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities: 
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Create an empty list to hold the weather data.
city_data= []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count= 1
set_count=1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    try:
        # Parse the JSON and retrieve data.
        city_weather= requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_description= city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bredasdorp
# Processing Record 2 of Set 1 | namibe
# Processing Record 3 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 4 of Set 1 | rikitea
# Processing Record 5 of Set 1 | isla aguada
# Processing Record 6 of Set 1 | mareeba
# Processing Record 7 of Set 1 | koumac
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 11 of Set 1 | fort nelson
# Processing Record 12 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | bam
# Processing Record 15 of Set 1 | kodiak
# Processing Record 16 of Set 1 | vestmannaeyjar
# Processing Record 17 of Set 1 | avera
# Processing Record 18 of Set 1 | vaini
# Processing Record 19 of Set 1 | hamilton
# Processing Record 20 of Set 1 | meulaboh
# Processing Record 21 of Set 1 | cayenne
# Processing Record 22 of Set 1 | kungurtug
# Processing Record 23 of Set 1 | pangkalanbuun
# Processing Record 24 of Set 1 | nanortalik
# Processing Record 25 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 26 of Set 1 | nyurba
# Processing Record 27 of Set 1 | mergui
# City not found. Skipping...
# Processing Record 28 of Set 1 | cabo san lucas
# Processing Record 29 of Set 1 | dikson
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 32 of Set 1 | vanimo
# Processing Record 33 of Set 1 | sento se
# City not found. Skipping...
# Processing Record 34 of Set 1 | punta arenas
# Processing Record 35 of Set 1 | nshamba
# Processing Record 36 of Set 1 | port alfred
# Processing Record 37 of Set 1 | atuona
# Processing Record 38 of Set 1 | kapaa
# Processing Record 39 of Set 1 | excelsior springs
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | alekseyevsk
# Processing Record 42 of Set 1 | matagalpa
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | san cristobal
# Processing Record 45 of Set 1 | ponta do sol
# Processing Record 46 of Set 1 | puerto narino
# Processing Record 47 of Set 1 | mar del plata
# Processing Record 48 of Set 1 | kurya
# Processing Record 49 of Set 1 | tasiilaq
# Processing Record 50 of Set 1 | jibuti
# Processing Record 1 of Set 2 | saint-georges
# Processing Record 2 of Set 2 | liaozhong
# Processing Record 3 of Set 2 | saint-philippe
# Processing Record 4 of Set 2 | maniitsoq
# Processing Record 5 of Set 2 | ekibastuz
# Processing Record 6 of Set 2 | tignere
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | nouadhibou
# Processing Record 9 of Set 2 | tual
# Processing Record 10 of Set 2 | lebu
# Processing Record 11 of Set 2 | pohrebyshche
# Processing Record 12 of Set 2 | hithadhoo
# Processing Record 13 of Set 2 | vilhena
# Processing Record 14 of Set 2 | batagay-alyta
# Processing Record 15 of Set 2 | muravlenko
# Processing Record 16 of Set 2 | kjollefjord
# Processing Record 17 of Set 2 | guerrero negro
# Processing Record 18 of Set 2 | galesong
# Processing Record 19 of Set 2 | hermanus
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | nouakchott
# Processing Record 22 of Set 2 | hofn
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | fortuna
# Processing Record 25 of Set 2 | riyadh
# Processing Record 26 of Set 2 | port hedland
# Processing Record 27 of Set 2 | albany
# Processing Record 28 of Set 2 | gorin
# Processing Record 29 of Set 2 | vilcun
# Processing Record 30 of Set 2 | boddam
# Processing Record 31 of Set 2 | upernavik
# Processing Record 32 of Set 2 | kyra
# Processing Record 33 of Set 2 | aklavik
# Processing Record 34 of Set 2 | golden
# Processing Record 35 of Set 2 | leningradskiy
# Processing Record 36 of Set 2 | camacha
# Processing Record 37 of Set 2 | padang
# Processing Record 38 of Set 2 | tukrah
# Processing Record 39 of Set 2 | lugovskiy
# City not found. Skipping...
# Processing Record 40 of Set 2 | toulepleu
# City not found. Skipping...
# Processing Record 41 of Set 2 | chokurdakh
# Processing Record 42 of Set 2 | sabana de torres
# Processing Record 43 of Set 2 | ponta delgada
# Processing Record 44 of Set 2 | the valley
# Processing Record 45 of Set 2 | isla vista
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | rawson
# Processing Record 49 of Set 2 | boa vista
# Processing Record 50 of Set 2 | rendsburg
# Processing Record 1 of Set 3 | naze
# Processing Record 2 of Set 3 | jalpan
# Processing Record 3 of Set 3 | lasa
# Processing Record 4 of Set 3 | new norfolk
# Processing Record 5 of Set 3 | kirensk
# Processing Record 6 of Set 3 | barrow
# Processing Record 7 of Set 3 | kharan
# Processing Record 8 of Set 3 | deputatskiy
# Processing Record 9 of Set 3 | georgetown
# Processing Record 10 of Set 3 | arraial do cabo
# Processing Record 11 of Set 3 | celestun
# Processing Record 12 of Set 3 | severo-kurilsk
# Processing Record 13 of Set 3 | caramay
# Processing Record 14 of Set 3 | thompson
# Processing Record 15 of Set 3 | yanaul
# Processing Record 16 of Set 3 | mahebourg
# Processing Record 17 of Set 3 | natalio
# Processing Record 18 of Set 3 | busselton
# Processing Record 19 of Set 3 | souillac
# Processing Record 20 of Set 3 | san vicente
# Processing Record 21 of Set 3 | bluff
# Processing Record 22 of Set 3 | hobart
# Processing Record 23 of Set 3 | kaitangata
# Processing Record 24 of Set 3 | badvel
# Processing Record 25 of Set 3 | nioro
# Processing Record 26 of Set 3 | santa isabel do rio negro
# Processing Record 27 of Set 3 | las cruces
# Processing Record 28 of Set 3 | hongan
# City not found. Skipping...
# Processing Record 29 of Set 3 | victoria
# Processing Record 30 of Set 3 | mazatlan
# Processing Record 31 of Set 3 | aneho
# Processing Record 32 of Set 3 | pacifica
# Processing Record 33 of Set 3 | abu kamal
# Processing Record 34 of Set 3 | grand-santi
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | butaritari
# Processing Record 37 of Set 3 | katsuura
# Processing Record 38 of Set 3 | khatanga
# Processing Record 39 of Set 3 | khakhea
# Processing Record 40 of Set 3 | te anau
# Processing Record 41 of Set 3 | copiapo
# Processing Record 42 of Set 3 | norman wells
# Processing Record 43 of Set 3 | yellowknife
# Processing Record 44 of Set 3 | saint george
# Processing Record 45 of Set 3 | keti bandar
# Processing Record 46 of Set 3 | phitsanulok
# Processing Record 47 of Set 3 | port elizabeth
# Processing Record 48 of Set 3 | filingue
# Processing Record 49 of Set 3 | sunland park
# Processing Record 50 of Set 3 | carros
# Processing Record 1 of Set 4 | santa rosalia
# Processing Record 2 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 4 | waddan
# Processing Record 4 of Set 4 | kuytun
# Processing Record 5 of Set 4 | griffith
# Processing Record 6 of Set 4 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 7 of Set 4 | kavaratti
# Processing Record 8 of Set 4 | chapais
# Processing Record 9 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 10 of Set 4 | narsaq
# Processing Record 11 of Set 4 | flinders
# Processing Record 12 of Set 4 | touros
# Processing Record 13 of Set 4 | san patricio
# Processing Record 14 of Set 4 | ancud
# Processing Record 15 of Set 4 | sao paulo de olivenca
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | takoradi
# Processing Record 18 of Set 4 | hua hin
# Processing Record 19 of Set 4 | buraydah
# Processing Record 20 of Set 4 | mehamn
# Processing Record 21 of Set 4 | asau
# Processing Record 22 of Set 4 | caxito
# Processing Record 23 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 24 of Set 4 | ilulissat
# Processing Record 25 of Set 4 | tyler
# Processing Record 26 of Set 4 | kahului
# Processing Record 27 of Set 4 | carnarvon
# Processing Record 28 of Set 4 | canico
# Processing Record 29 of Set 4 | ribeira grande
# Processing Record 30 of Set 4 | tura
# Processing Record 31 of Set 4 | namtsy
# Processing Record 32 of Set 4 | qaanaaq
# Processing Record 33 of Set 4 | lompoc
# Processing Record 34 of Set 4 | tilichiki
# Processing Record 35 of Set 4 | alofi
# Processing Record 36 of Set 4 | jamestown
# Processing Record 37 of Set 4 | iqaluit
# Processing Record 38 of Set 4 | aswan
# Processing Record 39 of Set 4 | vardo
# Processing Record 40 of Set 4 | birao
# Processing Record 41 of Set 4 | haapu
# City not found. Skipping...
# Processing Record 42 of Set 4 | cherskiy
# Processing Record 43 of Set 4 | bengkulu
# Processing Record 44 of Set 4 | krasnoselkup
# Processing Record 45 of Set 4 | razgrad
# Processing Record 46 of Set 4 | solnechnyy
# Processing Record 47 of Set 4 | borogontsy
# Processing Record 48 of Set 4 | warrington
# Processing Record 49 of Set 4 | port-gentil
# Processing Record 50 of Set 4 | haines junction
# Processing Record 1 of Set 5 | ossora
# Processing Record 2 of Set 5 | husavik
# Processing Record 3 of Set 5 | ambagarh chauki
# Processing Record 4 of Set 5 | dunedin
# Processing Record 5 of Set 5 | yilan
# Processing Record 6 of Set 5 | trelew
# Processing Record 7 of Set 5 | guilin
# Processing Record 8 of Set 5 | provideniya
# Processing Record 9 of Set 5 | talnakh
# Processing Record 10 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 5 | bereda
# Processing Record 12 of Set 5 | tromso
# Processing Record 13 of Set 5 | airai
# Processing Record 14 of Set 5 | clyde river
# Processing Record 15 of Set 5 | manaus
# Processing Record 16 of Set 5 | shebalino
# Processing Record 17 of Set 5 | zharkent
# Processing Record 18 of Set 5 | puerto ayora
# Processing Record 19 of Set 5 | manta
# Processing Record 20 of Set 5 | sioux lookout
# Processing Record 21 of Set 5 | bilma
# Processing Record 22 of Set 5 | oranjemund
# Processing Record 23 of Set 5 | port hardy
# Processing Record 24 of Set 5 | richards bay
# Processing Record 25 of Set 5 | andros town
# Processing Record 26 of Set 5 | bubaque
# Processing Record 27 of Set 5 | gamba
# Processing Record 28 of Set 5 | sur
# Processing Record 29 of Set 5 | alekseyevka
# Processing Record 30 of Set 5 | maine-soroa
# Processing Record 31 of Set 5 | fuling
# Processing Record 32 of Set 5 | saint-leu
# Processing Record 33 of Set 5 | strandby
# Processing Record 34 of Set 5 | kruisfontein
# Processing Record 35 of Set 5 | portland
# Processing Record 36 of Set 5 | college
# Processing Record 37 of Set 5 | soto la marina
# Processing Record 38 of Set 5 | masuguru
# Processing Record 39 of Set 5 | olafsvik
# Processing Record 40 of Set 5 | bara
# Processing Record 41 of Set 5 | gazojak
# Processing Record 42 of Set 5 | rio grande
# Processing Record 43 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 5 | chesma
# Processing Record 45 of Set 5 | lahat
# Processing Record 46 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 5 | atar
# Processing Record 48 of Set 5 | anito
# Processing Record 49 of Set 5 | ucluelet
# Processing Record 50 of Set 5 | constitucion
# Processing Record 1 of Set 6 | fuerte olimpo
# Processing Record 2 of Set 6 | doha
# Processing Record 3 of Set 6 | linjiang
# Processing Record 4 of Set 6 | sragen
# Processing Record 5 of Set 6 | nikolayevsk-na-amure
# Processing Record 6 of Set 6 | bolungarvik
# City not found. Skipping...
# Processing Record 7 of Set 6 | quelimane
# Processing Record 8 of Set 6 | pingliang
# Processing Record 9 of Set 6 | nikolskoye
# Processing Record 10 of Set 6 | hasaki
# Processing Record 11 of Set 6 | bayangol
# Processing Record 12 of Set 6 | puerto del rosario
# Processing Record 13 of Set 6 | muzhi
# Processing Record 14 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 15 of Set 6 | antalaha
# Processing Record 16 of Set 6 | ouegoa
# Processing Record 17 of Set 6 | ondorhaan
# City not found. Skipping...
# Processing Record 18 of Set 6 | coahuayana
# Processing Record 19 of Set 6 | kavieng
# Processing Record 20 of Set 6 | iquique
# Processing Record 21 of Set 6 | eureka
# Processing Record 22 of Set 6 | paamiut
# Processing Record 23 of Set 6 | port lincoln
# Processing Record 24 of Set 6 | tarudant
# City not found. Skipping...
# Processing Record 25 of Set 6 | pandan
# Processing Record 26 of Set 6 | ibitinga
# Processing Record 27 of Set 6 | kroonstad
# Processing Record 28 of Set 6 | acapulco
# Processing Record 29 of Set 6 | mpika
# Processing Record 30 of Set 6 | batangafo
# Processing Record 31 of Set 6 | bemidji
# Processing Record 32 of Set 6 | elliot lake
# Processing Record 33 of Set 6 | vostok
# Processing Record 34 of Set 6 | shubarshi
# Processing Record 35 of Set 6 | jalu
# Processing Record 36 of Set 6 | karratha
# Processing Record 37 of Set 6 | wasilla
# Processing Record 38 of Set 6 | beringovskiy
# Processing Record 39 of Set 6 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 6 | yulara
# Processing Record 41 of Set 6 | barabinsk
# Processing Record 42 of Set 6 | mount isa
# Processing Record 43 of Set 6 | kasama
# Processing Record 44 of Set 6 | okhotsk
# Processing Record 45 of Set 6 | kudahuvadhoo
# Processing Record 46 of Set 6 | soe
# Processing Record 47 of Set 6 | cuamba
# Processing Record 48 of Set 6 | codrington
# Processing Record 49 of Set 6 | los llanos de aridane
# Processing Record 50 of Set 6 | zaranj
# Processing Record 1 of Set 7 | along
# Processing Record 2 of Set 7 | loja
# Processing Record 3 of Set 7 | renqiu
# Processing Record 4 of Set 7 | gurupi
# Processing Record 5 of Set 7 | dakar
# Processing Record 6 of Set 7 | sao jose da tapera
# Processing Record 7 of Set 7 | jumla
# Processing Record 8 of Set 7 | san quintin
# Processing Record 9 of Set 7 | mayumba
# Processing Record 10 of Set 7 | birjand
# Processing Record 11 of Set 7 | puerto carreno
# Processing Record 12 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 7 | lavrentiya
# Processing Record 14 of Set 7 | jaciara
# Processing Record 15 of Set 7 | mocuba
# Processing Record 16 of Set 7 | simbahan
# Processing Record 17 of Set 7 | tanga
# Processing Record 18 of Set 7 | tuatapere
# Processing Record 19 of Set 7 | luganville
# Processing Record 20 of Set 7 | diego de almagro
# Processing Record 21 of Set 7 | turan
# Processing Record 22 of Set 7 | tezu
# Processing Record 23 of Set 7 | diffa
# Processing Record 24 of Set 7 | gusinoye ozero
# Processing Record 25 of Set 7 | floro
# Processing Record 26 of Set 7 | labuhan
# Processing Record 27 of Set 7 | pacific grove
# Processing Record 28 of Set 7 | henties bay
# Processing Record 29 of Set 7 | romilly-sur-seine
# Processing Record 30 of Set 7 | barcelos
# Processing Record 31 of Set 7 | kupang
# Processing Record 32 of Set 7 | fairview
# Processing Record 33 of Set 7 | margate
# Processing Record 34 of Set 7 | juneau
# Processing Record 35 of Set 7 | umm lajj
# Processing Record 36 of Set 7 | nome
# Processing Record 37 of Set 7 | ostrovnoy
# Processing Record 38 of Set 7 | nagar
# Processing Record 39 of Set 7 | lagoa
# Processing Record 40 of Set 7 | banjar
# Processing Record 41 of Set 7 | maumere
# Processing Record 42 of Set 7 | tessalit
# Processing Record 43 of Set 7 | alto araguaia
# Processing Record 44 of Set 7 | saint-pierre
# Processing Record 45 of Set 7 | batagay
# Processing Record 46 of Set 7 | vaitape
# Processing Record 47 of Set 7 | zemio
# Processing Record 48 of Set 7 | cidreira
# Processing Record 49 of Set 7 | culfa
# Processing Record 50 of Set 7 | broome
# Processing Record 1 of Set 8 | la malbaie
# Processing Record 2 of Set 8 | tartki
# City not found. Skipping...
# Processing Record 3 of Set 8 | vao
# Processing Record 4 of Set 8 | beruwala
# Processing Record 5 of Set 8 | sitka
# Processing Record 6 of Set 8 | el alto
# Processing Record 7 of Set 8 | east london
# Processing Record 8 of Set 8 | muscat
# Processing Record 9 of Set 8 | ginir
# Processing Record 10 of Set 8 | tabatinga
# Processing Record 11 of Set 8 | saint anthony
# Processing Record 12 of Set 8 | rio brilhante
# Processing Record 13 of Set 8 | nago
# Processing Record 14 of Set 8 | half moon bay
# Processing Record 15 of Set 8 | itaituba
# Processing Record 16 of Set 8 | saskylakh
# Processing Record 17 of Set 8 | yuli
# Processing Record 18 of Set 8 | chagda
# City not found. Skipping...
# Processing Record 19 of Set 8 | pisco
# Processing Record 20 of Set 8 | fougamou
# Processing Record 21 of Set 8 | verkhnevilyuysk
# Processing Record 22 of Set 8 | kirovskiy
# Processing Record 23 of Set 8 | mahabaleshwar
# Processing Record 24 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 8 | kasongo-lunda
# Processing Record 26 of Set 8 | lorengau
# Processing Record 27 of Set 8 | vestmanna
# Processing Record 28 of Set 8 | jiuquan
# Processing Record 29 of Set 8 | faya
# Processing Record 30 of Set 8 | seoul
# Processing Record 31 of Set 8 | dingle
# Processing Record 32 of Set 8 | sibiti
# Processing Record 33 of Set 8 | qui nhon
# Processing Record 34 of Set 8 | marsa matruh
# Processing Record 35 of Set 8 | ixtapa
# Processing Record 36 of Set 8 | adre
# Processing Record 37 of Set 8 | byron bay
# Processing Record 38 of Set 8 | wagar
# Processing Record 39 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 8 | champerico
# Processing Record 41 of Set 8 | fram
# Processing Record 42 of Set 8 | gillette
# Processing Record 43 of Set 8 | tabory
# Processing Record 44 of Set 8 | viedma
# Processing Record 45 of Set 8 | kalmunai
# Processing Record 46 of Set 8 | chifeng
# Processing Record 47 of Set 8 | lukovetskiy
# Processing Record 48 of Set 8 | kiunga
# Processing Record 49 of Set 8 | komsomolskiy
# Processing Record 50 of Set 8 | alyangula
# Processing Record 1 of Set 9 | poronaysk
# Processing Record 2 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 3 of Set 9 | sakakah
# Processing Record 4 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 5 of Set 9 | patan
# Processing Record 6 of Set 9 | da nang
# Processing Record 7 of Set 9 | la crosse
# Processing Record 8 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 9 of Set 9 | chuy
# Processing Record 10 of Set 9 | lata
# Processing Record 11 of Set 9 | erzin
# Processing Record 12 of Set 9 | scottsburgh
# City not found. Skipping...
# Processing Record 13 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 14 of Set 9 | marsh harbour
# Processing Record 15 of Set 9 | saldanha
# Processing Record 16 of Set 9 | lannion
# Processing Record 17 of Set 9 | grand gaube
# Processing Record 18 of Set 9 | benghazi
# Processing Record 19 of Set 9 | santa marta
# Processing Record 20 of Set 9 | hirado
# Processing Record 21 of Set 9 | havelock
# Processing Record 22 of Set 9 | suhbaatar
# Processing Record 23 of Set 9 | lazaro cardenas
# Processing Record 24 of Set 9 | tiznit
# Processing Record 25 of Set 9 | imbituba
# Processing Record 26 of Set 9 | comacchio
# Processing Record 27 of Set 9 | derbent
# Processing Record 28 of Set 9 | matara
# Processing Record 29 of Set 9 | luderitz
# Processing Record 30 of Set 9 | uberaba
# Processing Record 31 of Set 9 | dordrecht
# Processing Record 32 of Set 9 | nemuro
# Processing Record 33 of Set 9 | dhidhdhoo
# Processing Record 34 of Set 9 | sept-iles
# Processing Record 35 of Set 9 | pangai
# Processing Record 36 of Set 9 | cap malheureux
# Processing Record 37 of Set 9 | zeya
# Processing Record 38 of Set 9 | dukat
# Processing Record 39 of Set 9 | impfondo
# Processing Record 40 of Set 9 | varhaug
# Processing Record 41 of Set 9 | salalah
# Processing Record 42 of Set 9 | euclid
# Processing Record 43 of Set 9 | pilao arcado
# City not found. Skipping...
# Processing Record 44 of Set 9 | mecca
# Processing Record 45 of Set 9 | mariental
# Processing Record 46 of Set 9 | miraflores
# Processing Record 47 of Set 9 | phan rang
# City not found. Skipping...
# Processing Record 48 of Set 9 | cozumel
# Processing Record 49 of Set 9 | barmer
# Processing Record 50 of Set 9 | outlook
# Processing Record 1 of Set 10 | penzance
# Processing Record 2 of Set 10 | jertih
# Processing Record 3 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 4 of Set 10 | pahrump
# Processing Record 5 of Set 10 | santarem
# Processing Record 6 of Set 10 | aleksandrovsk-sakhalinskiy
# Processing Record 7 of Set 10 | otavi
# Processing Record 8 of Set 10 | mandali
# Processing Record 9 of Set 10 | freeport
# Processing Record 10 of Set 10 | quesnel
# Processing Record 11 of Set 10 | shakiso
# Processing Record 12 of Set 10 | ahuimanu
# Processing Record 13 of Set 10 | silver city
# Processing Record 14 of Set 10 | laguna
# Processing Record 15 of Set 10 | bilibino
# Processing Record 16 of Set 10 | tucupita
# Processing Record 17 of Set 10 | ust-maya
# Processing Record 18 of Set 10 | milkovo
# Processing Record 19 of Set 10 | onega
# Processing Record 20 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 21 of Set 10 | vila velha
# Processing Record 22 of Set 10 | kaniama
# Processing Record 23 of Set 10 | balkhash
# Processing Record 24 of Set 10 | acuna
# City not found. Skipping...
# Processing Record 25 of Set 10 | pangnirtung
# Processing Record 26 of Set 10 | qasigiannguit
# Processing Record 27 of Set 10 | pak phanang
# Processing Record 28 of Set 10 | avallon
# Processing Record 29 of Set 10 | sao filipe
# Processing Record 30 of Set 10 | marawi
# Processing Record 31 of Set 10 | piopio
# Processing Record 32 of Set 10 | teplodar
# Processing Record 33 of Set 10 | muros
# Processing Record 34 of Set 10 | amazar
# Processing Record 35 of Set 10 | tvoroyri
# Processing Record 36 of Set 10 | goure
# Processing Record 37 of Set 10 | kushima
# Processing Record 38 of Set 10 | axim
# Processing Record 39 of Set 10 | sao joao da barra
# Processing Record 40 of Set 10 | saint-augustin
# Processing Record 41 of Set 10 | tamworth
# Processing Record 42 of Set 10 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 10 | rocha
# Processing Record 44 of Set 10 | santa maria
# Processing Record 45 of Set 10 | krasnoborsk
# Processing Record 46 of Set 10 | geraldton
# Processing Record 47 of Set 10 | esso
# Processing Record 48 of Set 10 | george
# Processing Record 49 of Set 10 | almeirim
# Processing Record 50 of Set 10 | narayanpet
# Processing Record 1 of Set 11 | knysna
# Processing Record 2 of Set 11 | klaksvik
# Processing Record 3 of Set 11 | hovd
# Processing Record 4 of Set 11 | marrakesh
# Processing Record 5 of Set 11 | taga
# Processing Record 6 of Set 11 | luebo
# Processing Record 7 of Set 11 | corn island
# Processing Record 8 of Set 11 | bethel
# Processing Record 9 of Set 11 | atkarsk
# Processing Record 10 of Set 11 | atambua
# Processing Record 11 of Set 11 | batemans bay
# Processing Record 12 of Set 11 | caluquembe
# Processing Record 13 of Set 11 | leh
# Processing Record 14 of Set 11 | road town
# Processing Record 15 of Set 11 | kulhudhuffushi
# Processing Record 16 of Set 11 | suntar
# Processing Record 17 of Set 11 | faanui
# Processing Record 18 of Set 11 | kloulklubed
# Processing Record 19 of Set 11 | esperance
# Processing Record 20 of Set 11 | sambava
# Processing Record 21 of Set 11 | grenaa
# Processing Record 22 of Set 11 | lovozero
# Processing Record 23 of Set 11 | yarmouth
# Processing Record 24 of Set 11 | aguimes
# Processing Record 25 of Set 11 | ust-tsilma
# Processing Record 26 of Set 11 | mount gambier
# Processing Record 27 of Set 11 | pevek
# Processing Record 28 of Set 11 | pedernales
# Processing Record 29 of Set 11 | ternate
# Processing Record 30 of Set 11 | pocone
# Processing Record 31 of Set 11 | tabou
# Processing Record 32 of Set 11 | kamina
# Processing Record 33 of Set 11 | mafinga
# Processing Record 34 of Set 11 | buariki
# City not found. Skipping...
# Processing Record 35 of Set 11 | albion
# Processing Record 36 of Set 11 | ilo
# Processing Record 37 of Set 11 | hambantota
# Processing Record 38 of Set 11 | moerai
# Processing Record 39 of Set 11 | kuldur
# Processing Record 40 of Set 11 | sabha
# Processing Record 41 of Set 11 | dawson creek
# Processing Record 42 of Set 11 | krasnoarmeysk
# Processing Record 43 of Set 11 | weligama
# Processing Record 44 of Set 11 | sayyan
# Processing Record 45 of Set 11 | banda aceh
# Processing Record 46 of Set 11 | navoloki
# Processing Record 47 of Set 11 | lixourion
# Processing Record 48 of Set 11 | buchanan
# Processing Record 49 of Set 11 | ampanihy
# Processing Record 50 of Set 11 | sembe
# Processing Record 1 of Set 12 | sorong
# Processing Record 2 of Set 12 | mezen
# Processing Record 3 of Set 12 | kainantu
# Processing Record 4 of Set 12 | sibolga
# Processing Record 5 of Set 12 | marsaxlokk
# Processing Record 6 of Set 12 | turkistan
# Processing Record 7 of Set 12 | daru
# Processing Record 8 of Set 12 | lubango
# Processing Record 9 of Set 12 | mahajanga
# Processing Record 10 of Set 12 | mayo
# Processing Record 11 of Set 12 | sauce
# Processing Record 12 of Set 12 | krasnovishersk
# Processing Record 13 of Set 12 | mbekenyera
# Processing Record 14 of Set 12 | gasa
# Processing Record 15 of Set 12 | necochea
# Processing Record 16 of Set 12 | tsiroanomandidy
# Processing Record 17 of Set 12 | virginia beach
# Processing Record 18 of Set 12 | itamaraju
# Processing Record 19 of Set 12 | capanema
# Processing Record 20 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 12 | tshikapa
# Processing Record 22 of Set 12 | high level
# Processing Record 23 of Set 12 | ercis
# Processing Record 24 of Set 12 | yumen
# Processing Record 25 of Set 12 | rio grande city
# Processing Record 26 of Set 12 | jaguarao
# Processing Record 27 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 28 of Set 12 | muisne
# Processing Record 29 of Set 12 | praia da vitoria
# Processing Record 30 of Set 12 | grindavik
# Processing Record 31 of Set 12 | howard springs
# Processing Record 32 of Set 12 | coracora
# Processing Record 33 of Set 12 | gayny
# Processing Record 34 of Set 12 | namatanai
# Processing Record 35 of Set 12 | mogadishu
# Processing Record 36 of Set 12 | new amsterdam
# Processing Record 37 of Set 12 | zemetchino
# Processing Record 38 of Set 12 | gurupa
# Processing Record 39 of Set 12 | beba
# Processing Record 40 of Set 12 | ardahan
# Processing Record 41 of Set 12 | east wenatchee bench
# Processing Record 42 of Set 12 | poso
# Processing Record 43 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 44 of Set 12 | kualakapuas
# Processing Record 45 of Set 12 | izmit
# Processing Record 46 of Set 12 | shilovo
# Processing Record 47 of Set 12 | macas
# Processing Record 48 of Set 12 | meyungs
# City not found. Skipping...
# Processing Record 49 of Set 12 | san carlos de bariloche
# Processing Record 50 of Set 12 | larap
# Processing Record 1 of Set 13 | coihaique
# Processing Record 2 of Set 13 | mount pleasant
# Processing Record 3 of Set 13 | agogo
# Processing Record 4 of Set 13 | longkou
# Processing Record 5 of Set 13 | petropavlovka
# Processing Record 6 of Set 13 | qaqortoq
# Processing Record 7 of Set 13 | coquimbo
# Processing Record 8 of Set 13 | eenhana
# Processing Record 9 of Set 13 | tari
# Processing Record 10 of Set 13 | kandiaro
# Processing Record 11 of Set 13 | okha
# Processing Record 12 of Set 13 | houston
# Processing Record 13 of Set 13 | mackay
# Processing Record 14 of Set 13 | tibiri
# Processing Record 15 of Set 13 | sunbury
# Processing Record 16 of Set 13 | bend
# Processing Record 17 of Set 13 | nyagan
# Processing Record 18 of Set 13 | paita
# Processing Record 19 of Set 13 | meadow lake
# Processing Record 20 of Set 13 | berdigestyakh
# Processing Record 21 of Set 13 | orlik
# Processing Record 22 of Set 13 | maneadero
# Processing Record 23 of Set 13 | nioaque
# Processing Record 24 of Set 13 | pangody
# Processing Record 25 of Set 13 | goderich
# Processing Record 26 of Set 13 | jega
# Processing Record 27 of Set 13 | ambilobe
# Processing Record 28 of Set 13 | toora-khem
# Processing Record 29 of Set 13 | ipojuca
# Processing Record 30 of Set 13 | brae
# Processing Record 31 of Set 13 | paoua
# Processing Record 32 of Set 13 | ngukurr
# City not found. Skipping...
# Processing Record 33 of Set 13 | riohacha
# Processing Record 34 of Set 13 | ciudad guayana
# Processing Record 35 of Set 13 | gorontalo
# Processing Record 36 of Set 13 | taltal
# Processing Record 37 of Set 13 | kesennuma
# City not found. Skipping...
# Processing Record 38 of Set 13 | mandvi
# Processing Record 39 of Set 13 | alta floresta
# Processing Record 40 of Set 13 | honiara
# Processing Record 41 of Set 13 | tautira
# Processing Record 42 of Set 13 | tasbuget
# City not found. Skipping...
# Processing Record 43 of Set 13 | karaton
# Processing Record 44 of Set 13 | kenai
# Processing Record 45 of Set 13 | bendigo
# Processing Record 46 of Set 13 | praia
# Processing Record 47 of Set 13 | kysyl-syr
# Processing Record 48 of Set 13 | warrnambool
# Processing Record 49 of Set 13 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 13 | westport
# Processing Record 1 of Set 14 | mopti
# Processing Record 2 of Set 14 | pitimbu
# Processing Record 3 of Set 14 | moen
# Processing Record 4 of Set 14 | beirut
# Processing Record 5 of Set 14 | kutum
# Processing Record 6 of Set 14 | cantanhede
# Processing Record 7 of Set 14 | san andres
# Processing Record 8 of Set 14 | hay river
# Processing Record 9 of Set 14 | bangkalan
# Processing Record 10 of Set 14 | grand-lahou
# Processing Record 11 of Set 14 | libacao
# Processing Record 12 of Set 14 | ramshir
# Processing Record 13 of Set 14 | santa lucia
# Processing Record 14 of Set 14 | sola
# Processing Record 15 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 16 of Set 14 | miyoshi
# Processing Record 17 of Set 14 | waki
# Processing Record 18 of Set 14 | broken hill
# Processing Record 19 of Set 14 | adjumani
# Processing Record 20 of Set 14 | la ronge
# Processing Record 21 of Set 14 | merauke
# Processing Record 22 of Set 14 | toccoa
# Processing Record 23 of Set 14 | okmulgee
# Processing Record 24 of Set 14 | kununurra
# Processing Record 25 of Set 14 | fano
# Processing Record 26 of Set 14 | wawa
# Processing Record 27 of Set 14 | tokat
# Processing Record 28 of Set 14 | beira
# Processing Record 29 of Set 14 | aleksandrov gay
# Processing Record 30 of Set 14 | korla
# Processing Record 31 of Set 14 | kermanshah
# Processing Record 32 of Set 14 | kushmurun
# Processing Record 33 of Set 14 | maple creek
# Processing Record 34 of Set 14 | upata
# Processing Record 35 of Set 14 | roald
# Processing Record 36 of Set 14 | gameza
# Processing Record 37 of Set 14 | liverpool
# Processing Record 38 of Set 14 | dagua
# Processing Record 39 of Set 14 | senador guiomard
# Processing Record 40 of Set 14 | monrovia
# Processing Record 41 of Set 14 | camargo
# Processing Record 42 of Set 14 | agnibilekrou
# Processing Record 43 of Set 14 | rincon
# Processing Record 44 of Set 14 | mastic
# Processing Record 45 of Set 14 | semey
# Processing Record 46 of Set 14 | samarai
# Processing Record 47 of Set 14 | flin flon
# Processing Record 48 of Set 14 | smithers
# Processing Record 49 of Set 14 | gyanpur
# Processing Record 50 of Set 14 | mongu
# Processing Record 1 of Set 15 | les cayes
# Processing Record 2 of Set 15 | pathein
# Processing Record 3 of Set 15 | mino
# Processing Record 4 of Set 15 | santona
# Processing Record 5 of Set 15 | polyarnyy
# Processing Record 6 of Set 15 | teruel
# Processing Record 7 of Set 15 | miramar
# Processing Record 8 of Set 15 | horta
# Processing Record 9 of Set 15 | bathsheba
# Processing Record 10 of Set 15 | santa rita
# Processing Record 11 of Set 15 | tairua
# Processing Record 12 of Set 15 | kidal
# Processing Record 13 of Set 15 | piacabucu
# Processing Record 14 of Set 15 | moosburg
# Processing Record 15 of Set 15 | tulun
# Processing Record 16 of Set 15 | khasan
# Processing Record 17 of Set 15 | wajima
# Processing Record 18 of Set 15 | nusaybin
# Processing Record 19 of Set 15 | tarakan
# Processing Record 20 of Set 15 | calvinia
# Processing Record 21 of Set 15 | mocambique
# City not found. Skipping...
# Processing Record 22 of Set 15 | hervey bay
# Processing Record 23 of Set 15 | svay rieng
# Processing Record 24 of Set 15 | tingrela
# City not found. Skipping...
# Processing Record 25 of Set 15 | bud
# Processing Record 26 of Set 15 | palabuhanratu
# City not found. Skipping...
# Processing Record 27 of Set 15 | vila franca do campo
# Processing Record 28 of Set 15 | north platte
# Processing Record 29 of Set 15 | manyana
# Processing Record 30 of Set 15 | lakatoro
# Processing Record 31 of Set 15 | ambon
# Processing Record 32 of Set 15 | yaan
# Processing Record 33 of Set 15 | pokhara
# Processing Record 34 of Set 15 | lugoba
# Processing Record 35 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 15 | shadrinsk
# Processing Record 37 of Set 15 | salawagan
# Processing Record 38 of Set 15 | shache
# Processing Record 39 of Set 15 | antofagasta
# Processing Record 40 of Set 15 | hualmay
# Processing Record 41 of Set 15 | luan
# Processing Record 42 of Set 15 | wageningen
# Processing Record 43 of Set 15 | baykit
# Processing Record 44 of Set 15 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 15 | molchanovo
# Processing Record 46 of Set 15 | landau
# Processing Record 47 of Set 15 | gat
# Processing Record 48 of Set 15 | marfino
# Processing Record 49 of Set 15 | jadu
# Processing Record 50 of Set 15 | yasnyy
# Processing Record 1 of Set 16 | whitefish
# Processing Record 2 of Set 16 | freetown
# Processing Record 3 of Set 16 | sao miguel do araguaia
# Processing Record 4 of Set 16 | plettenberg bay
# Processing Record 5 of Set 16 | tortosa
# Processing Record 6 of Set 16 | anilao
# Processing Record 7 of Set 16 | anloga
# Processing Record 8 of Set 16 | alexandria
# Processing Record 9 of Set 16 | brigantine
# Processing Record 10 of Set 16 | jinxiang
# Processing Record 11 of Set 16 | adrar
# Processing Record 12 of Set 16 | luau
# Processing Record 13 of Set 16 | wamba
# Processing Record 14 of Set 16 | poya
# Processing Record 15 of Set 16 | fez
# Processing Record 16 of Set 16 | lagos
# Processing Record 17 of Set 16 | puerto suarez
# Processing Record 18 of Set 16 | maceio
# Processing Record 19 of Set 16 | bonito
# Processing Record 20 of Set 16 | stelle
# Processing Record 21 of Set 16 | tsentralnyy
# City not found. Skipping...
# Processing Record 22 of Set 16 | pervomayskiy
# Processing Record 23 of Set 16 | phan thiet
# Processing Record 24 of Set 16 | suez
# Processing Record 25 of Set 16 | pinega
# Processing Record 26 of Set 16 | ajdabiya
# Processing Record 27 of Set 16 | andenes
# Processing Record 28 of Set 16 | pemangkat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Reorder the column names
new_column_order=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df=city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0   Bredasdorp      ZA -34.5322   20.0403     63.28        75          99
# 1       Namibe      AO -15.1961   12.1522     75.13        84         100
# 2      Rikitea      PF -23.1203 -134.9692     74.03        86         100
# 3  Isla Aguada      MX  18.7833  -91.4667     75.38        86          66
# 4      Mareeba      AU -17.0000  145.4333     88.66        71          26
# 5       Koumac      NC -20.5667  164.2833     86.77        59          22
# 6      Mataura      NZ -46.1927  168.8643     74.48        36           5
# 7       Avarua      CK -21.2078 -159.7750     80.65        83          40
# 8  Fort Nelson      CA  58.8053 -122.7002    -14.87        96          70
# 9       Castro      BR -24.7911  -50.0119     63.25        83           7
#
#    Wind Speed Current Description
# 0        4.92     overcast clouds
# 1        8.75     overcast clouds
# 2        8.32       moderate rain
# 3       12.84       broken clouds
# 4        3.49    scattered clouds
# 5        2.46          few clouds
# 6        3.15           clear sky
# 7       17.27          light rain
# 8        0.94       broken clouds
# 9        3.62           clear sky

# %%
# Export as a csv file
city_data_df.to_csv("WeatherPy_Database.csv")
